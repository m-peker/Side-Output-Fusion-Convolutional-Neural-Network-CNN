# %% [markdown]
# ## Side Output Fusion Convolutional Neural Network

# %% [markdown]
# The deep learning architecture, called Side Output Fusion Network, classifies the feature map obtained by combining low-level, mid-level and high-level information from each convolution layer. Feature fusion from low and high level layers positively affects the results.
#
# <img src="./data/Figure.png" width="750" height="750">

# %%
# Importing

from matplotlib import pyplot as plt
from keras import models
from keras.models import Model, Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, Input, Convolution2D, MaxPooling2D 
from keras.layers.normalization import BatchNormalization
import numpy as np
from keras.utils import np_utils
import keras
from keras.datasets import cifar10
from keras.layers.merge import concatenate

# Since I have a GPU related problem on my computer, I disabled GPU.
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"    
import tensorflow as tf

# Parameter Settings
num_classes  = 10  # Number of Classes
batch_size   = 128 # Batch Size
epochs       = 3 # Epoch number

# Data Distrubiton; Traing/Testing Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

img_rows, img_cols = 32, 32

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 3)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Creating Model

inputs = Input(shape=input_shape)

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(inputs)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#---Side 1 branch ---
s_1_bch = Flatten(name='side1_flatten')(x)
sideoutput1=s_1_bch
s_1_bch = Dense(256, activation='relu', name='side1_fc1')(s_1_bch)
s_1_bch = BatchNormalization()(s_1_bch)
s_1_bch = Dropout(0.5)(s_1_bch)
s_1_bch = Dense(256, activation='relu', name='side1_fc2')(s_1_bch)
s_1_bch = BatchNormalization()(s_1_bch)
s_1_bch = Dropout(0.5)(s_1_bch)
s_1_pred = Dense(num_classes, activation='softmax', name='side1_predictions')(s_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- Side 2 branch ---
s_2_bch = Flatten(name='c2_flatten')(x)
sideoutput2=s_2_bch 
s_2_bch = Dense(512, activation='relu', name='side2_fc1')(s_2_bch)
s_2_bch = BatchNormalization()(s_2_bch)
s_2_bch = Dropout(0.5)(s_2_bch)
s_2_bch = Dense(512, activation='relu', name='side2_fc2')(s_2_bch)
s_2_bch = BatchNormalization()(s_2_bch)
s_2_bch = Dropout(0.5)(s_2_bch)
s_2_pred = Dense(num_classes, activation='softmax', name='side2_predictions')(s_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- Side3 (Last) block ---
x = Flatten(name='flatten')(x)
sideoutput3=x
x = Dense(1024, activation='relu', name='side3_fc1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', name='side3_fc2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
side3_pred = Dense(num_classes, activation='softmax', name='side3_predictions')(x)

# Fusion Network
fusionfeatures=concatenate([sideoutput1, sideoutput2,sideoutput3])
fusion = Dense(1024, activation='relu', name='fusion_fc1')(fusionfeatures)
fusion = BatchNormalization()(fusion)
fusion = Dropout(0.5)(fusion)
fusion = Dense(1024, activation='relu', name='fusion_fc2')(fusion)
fusion = BatchNormalization()(fusion)
fusion = Dropout(0.5)(fusion)
fusion_pred = Dense(num_classes, activation='softmax', name='fusion_predictions')(fusion)

# We will run 4 different models at once without additional adjustment.
model = Model(input=inputs, output=[s_1_pred, s_2_pred, side3_pred, fusion_pred], name='our_model')
model.summary()

# Training Parameters
sgd = optimizers.SGD(lr=0.003, momentum=0.9, nesterov=True)

model.compile(optimizer='adam',
              loss=['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'],
              loss_weights=[0.05, 0.1, 1.0, 1.0],
              metrics=['accuracy'])

# Training Stage
model.fit(x_train,  [y_train, y_train, y_train,y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split = 0.15)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 10)
# C:\Users\alisu\Anaconda3\lib\site-packages\ipykernel_launcher.py:121: UserWarning: Update your `Model` call to the Keras 2 API: `Model(name="our_model", inputs=Tensor("in..., outputs=[<tf.Tenso...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 16, 16, 128)  512         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 16, 16, 128)  512         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 8, 8, 256)    1024        block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 8, 8, 256)    1024        block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 4, 4, 512)    2048        block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 4, 4, 512)    2048        block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 2, 2, 512)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# side1_flatten (Flatten)         (None, 8192)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 4096)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           block4_pool[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 14336)        0           side1_flatten[0][0]
#                                                                  c2_flatten[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# side1_fc1 (Dense)               (None, 256)          2097408     side1_flatten[0][0]
# __________________________________________________________________________________________________
# side2_fc1 (Dense)               (None, 512)          2097664     c2_flatten[0][0]
# __________________________________________________________________________________________________
# side3_fc1 (Dense)               (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# fusion_fc1 (Dense)              (None, 1024)         14681088    concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 256)          1024        side1_fc1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 512)          2048        side2_fc1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 1024)         4096        side3_fc1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 1024)         4096        fusion_fc1[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 256)          0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 512)          0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 1024)         0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 1024)         0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# side1_fc2 (Dense)               (None, 256)          65792       dropout_89[0][0]
# __________________________________________________________________________________________________
# side2_fc2 (Dense)               (None, 512)          262656      dropout_91[0][0]
# __________________________________________________________________________________________________
# side3_fc2 (Dense)               (None, 1024)         1049600     dropout_93[0][0]
# __________________________________________________________________________________________________
# fusion_fc2 (Dense)              (None, 1024)         1049600     dropout_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 256)          1024        side1_fc2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 512)          2048        side2_fc2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 1024)         4096        side3_fc2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 1024)         4096        fusion_fc2[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 256)          0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 512)          0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 1024)         0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 1024)         0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# side1_predictions (Dense)       (None, 10)           2570        dropout_90[0][0]
# __________________________________________________________________________________________________
# side2_predictions (Dense)       (None, 10)           5130        dropout_92[0][0]
# __________________________________________________________________________________________________
# side3_predictions (Dense)       (None, 10)           10250       dropout_94[0][0]
# __________________________________________________________________________________________________
# fusion_predictions (Dense)      (None, 10)           10250       dropout_96[0][0]
# ==================================================================================================
# Total params: 28,145,768
# Trainable params: 28,130,664
# Non-trainable params: 15,104
# __________________________________________________________________________________________________
# Train on 42500 samples, validate on 7500 samples
# Epoch 1/3
# 42500/42500 [==============================] - 3173s 75ms/step - loss: 0.5518 - side1_predictions_loss: 0.2612 - side2_predictions_loss: 0.2560 - side3_predictions_loss: 0.2626 - fusion_predictions_loss: 0.2505 - side1_predictions_acc: 0.9063 - side2_predictions_acc: 0.9086 - side3_predictions_acc: 0.9088 - fusion_predictions_acc: 0.9120 - val_loss: 0.4690 - val_side1_predictions_loss: 0.2080 - val_side2_predictions_loss: 0.2231 - val_side3_predictions_loss: 0.2263 - val_fusion_predictions_loss: 0.2100 - val_side1_predictions_acc: 0.9196 - val_side2_predictions_acc: 0.9178 - val_side3_predictions_acc: 0.9138 - val_fusion_predictions_acc: 0.9203
# Epoch 2/3
# 42500/42500 [==============================] - 2659s 63ms/step - loss: 0.3857 - side1_predictions_loss: 0.1856 - side2_predictions_loss: 0.1730 - side3_predictions_loss: 0.1837 - fusion_predictions_loss: 0.1755 - side1_predictions_acc: 0.9290 - side2_predictions_acc: 0.9347 - side3_predictions_acc: 0.9351 - fusion_predictions_acc: 0.9369 - val_loss: 0.8014 - val_side1_predictions_loss: 0.2489 - val_side2_predictions_loss: 0.3647 - val_side3_predictions_loss: 0.4068 - val_fusion_predictions_loss: 0.3456 - val_side1_predictions_acc: 0.9094 - val_side2_predictions_acc: 0.8904 - val_side3_predictions_acc: 0.8859 - val_fusion_predictions_acc: 0.9003
# Epoch 3/3
# 42500/42500 [==============================] - 3381s 80ms/step - loss: 0.3110 - side1_predictions_loss: 0.1605 - side2_predictions_loss: 0.1453 - side3_predictions_loss: 0.1455 - fusion_predictions_loss: 0.1430 - side1_predictions_acc: 0.9377 - side2_predictions_acc: 0.9438 - side3_predictions_acc: 0.9452 - fusion_predictions_acc: 0.9456 - val_loss: 0.3486 - val_side1_predictions_loss: 0.1470 - val_side2_predictions_loss: 0.1481 - val_side3_predictions_loss: 0.1760 - val_fusion_predictions_loss: 0.1504 - val_side1_predictions_acc: 0.9416 - val_side2_predictions_acc: 0.9446 - val_side3_predictions_acc: 0.9369 - val_fusion_predictions_acc: 0.9449
